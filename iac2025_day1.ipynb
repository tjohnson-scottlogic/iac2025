# %% [markdown]
# <a href="https://colab.research.google.com/github/tjohnson-scottlogic/iac2025/blob/main/iac2025_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Initial file for opening in Colab
print ("Hello Tim")
print ("This is new")
# Out:
# Hello Tim
# This is new
