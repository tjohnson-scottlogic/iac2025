# %% [markdown]
# <a href="https://colab.research.google.com/github/tjohnson-scottlogic/aoc2025/blob/main/day09/day09b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

for each position
  calculate rectangle against every other position

"""
# Out:
# '\n\nfor each position\n  calculate rectangle against every other position\n\n'

# %%
#FILENAME = "test.txt"
FILENAME = "sample.txt"
#FILENAME = "input.txt"

current_rectangle_area = 0
largest_rectangle_area = 0

# %%
with open(FILENAME, "r") as location:
  locations = location.read().splitlines()

for location in locations:
  print(f"location is {location}")
  location = location.split(",")
  for other_location in locations:
    other_location = other_location.split(",")
    print(f"other_location is {other_location}")
    current_rectangle_area = abs(((int(other_location[0]) - int(location[0])) + 1) *
                                 ((int(other_location[1]) - int(location[1])) + 1))
    print(f"current_rectangle_area = {current_rectangle_area}")
    if (current_rectangle_area > largest_rectangle_area):
      largest_rectangle_area = current_rectangle_area

print(f"largest_rectangle_area = {largest_rectangle_area}")
# Out:
# location is 7,1
# other_location is ['7', '1']
# current_rectangle_area = 1
# other_location is ['11', '1']
# current_rectangle_area = 5
# other_location is ['11', '7']
# current_rectangle_area = 35
# other_location is ['9', '7']
# current_rectangle_area = 21
# other_location is ['9', '5']
# current_rectangle_area = 15
# other_location is ['2', '5']
# current_rectangle_area = 20
# other_location is ['2', '3']
# current_rectangle_area = 12
# other_location is ['7', '3']
# current_rectangle_area = 3
# location is 11,1
# other_location is ['7', '1']
# current_rectangle_area = 3
# other_location is ['11', '1']
# current_rectangle_area = 1
# other_location is ['11', '7']
# current_rectangle_area = 7
# other_location is ['9', '7']
# current_rectangle_area = 7
# other_location is ['9', '5']
# current_rectangle_area = 5
# other_location is ['2', '5']
# current_rectangle_area = 40
# other_location is ['2', '3']
# current_rectangle_area = 24
# other_location is ['7', '3']
# current_rectangle_area = 9
# location is 11,7
# other_location is ['7', '1']
# current_rectangle_area = 15
# other_location is ['11', '1']
# current_rectangle_area = 5
# other_location is ['11', '7']
# current_rectangle_area = 1
# other_location is ['9', '7']
# current_rectangle_area = 1
# other_location is ['9', '5']
# current_rectangle_area = 1
# other_location is ['2', '5']
# current_rectangle_area = 8
# other_location is ['2', '3']
# current_rectangle_area = 24
# other_location is ['7', '3']
# current_rectangle_area = 9
# location is 9,7
# other_location is ['7', '1']
# current_rectangle_area = 5
# other_location is ['11', '1']
# current_rectangle_area = 15
# other_location is ['11', '7']
# current_rectangle_area = 3
# other_location is ['9', '7']
# current_rectangle_area = 1
# other_location is ['9', '5']
# current_rectangle_area = 1
# other_location is ['2', '5']
# current_rectangle_area = 6
# other_location is ['2', '3']
# current_rectangle_area = 18
# other_location is ['7', '3']
# current_rectangle_area = 3
# location is 9,5
# other_location is ['7', '1']
# current_rectangle_area = 3
# other_location is ['11', '1']
# current_rectangle_area = 9
# other_location is ['11', '7']
# current_rectangle_area = 9
# other_location is ['9', '7']
# current_rectangle_area = 3
# other_location is ['9', '5']
# current_rectangle_area = 1
# other_location is ['2', '5']
# current_rectangle_area = 6
# other_location is ['2', '3']
# current_rectangle_area = 6
# other_location is ['7', '3']
# current_rectangle_area = 1
# location is 2,5
# other_location is ['7', '1']
# current_rectangle_area = 18
# other_location is ['11', '1']
# current_rectangle_area = 30
# other_location is ['11', '7']
# current_rectangle_area = 30
# other_location is ['9', '7']
# current_rectangle_area = 24
# other_location is ['9', '5']
# current_rectangle_area = 8
# other_location is ['2', '5']
# current_rectangle_area = 1
# other_location is ['2', '3']
# current_rectangle_area = 1
# other_location is ['7', '3']
# current_rectangle_area = 6
# location is 2,3
# other_location is ['7', '1']
# current_rectangle_area = 6
# other_location is ['11', '1']
# current_rectangle_area = 10
# other_location is ['11', '7']
# current_rectangle_area = 50
# other_location is ['9', '7']
# current_rectangle_area = 40
# other_location is ['9', '5']
# current_rectangle_area = 24
# other_location is ['2', '5']
# current_rectangle_area = 3
# other_location is ['2', '3']
# current_rectangle_area = 1
# other_location is ['7', '3']
# current_rectangle_area = 6
# location is 7,3
# other_location is ['7', '1']
# current_rectangle_area = 1
# other_location is ['11', '1']
# current_rectangle_area = 5
# other_location is ['11', '7']
# current_rectangle_area = 25
# other_location is ['9', '7']
# current_rectangle_area = 15
# other_location is ['9', '5']
# current_rectangle_area = 9
# other_location is ['2', '5']
# current_rectangle_area = 12
# other_location is ['2', '3']
# current_rectangle_area = 4
# other_location is ['7', '3']
# current_rectangle_area = 1
# largest_rectangle_area = 50
