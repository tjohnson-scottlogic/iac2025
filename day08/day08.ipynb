# %% [markdown]
# <a href="https://colab.research.google.com/github/tjohnson-scottlogic/aoc2025/blob/main/day08/day08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""

position = [x,y,z]
positions = [position1, position2]
circuit = [position1, position2]
list_of_circuits = [circuit1, circuit2]

# First need to find all the distances between the points and sort them such that the shortest distance is first
# Then, processing from shortest distance, for a max of 1000, look to see if one of the pair is already part of a circuit, if it is then add to it, otherwise create a new one
# If both are already part of the same circuit then nothing happens
# If both are parts of existing different circuits, then add the circuits together and wipe one of the circuit lists
# Multiply together the sizes of the three largest circuits

For each box
  For every other box
    Calculate distance

"""
# Out:
# '\n\nposition = [x,y,z]\npositions = [position1, position2]\ncircuit = [position1, position2]\nlist_of_circuits = [circuit1, circuit2]\n\n# First need to find all the distances between the points and sort them such that the shortest distance is first\n# Then, processing from shortest distance, for a max of 1000, look to see if one of the pair is already part of a circuit, if it is then add to it, otherwise create a new one\n# If both are already part of the same circuit then nothing happens\n# If both are parts of existing different circuits, then add the circuits together and wipe one of the circuit lists\n# Multiply together the sizes of the three largest circuits\n\nFor each box\n  For every other box\n    Calculate distance\n\n'

# %%
positions = []

# %%
#text_file = "test.txt"
text_file = "sample.txt"
#text_file = "input.txt"

with open(text_file, "r") as position:
  positions = position.read().splitlines()
  print(positions)
# Out:
# ['162,817,812', '57,618,57', '906,360,560', '592,479,940', '352,342,300', '466,668,158', '542,29,236', '431,825,988', '739,650,466', '52,470,668', '216,146,977', '819,987,18', '117,168,530', '805,96,715', '346,949,466', '970,615,88', '941,993,340', '862,61,35', '984,92,344', '425,690,689']

# %%
for position in positions:
# Out:
# 162,817,812
# 57,618,57
# 906,360,560
# 592,479,940
# 352,342,300
# 466,668,158
# 542,29,236
# 431,825,988
# 739,650,466
# 52,470,668
# 216,146,977
# 819,987,18
# 117,168,530
# 805,96,715
# 346,949,466
# 970,615,88
# 941,993,340
# 862,61,35
# 984,92,344
# 425,690,689
